# %%
messages = ["Explain differences between Agentic AI and Generative AI in  way", "Capital of India is ?"]
complex_keywords = ["analysis", "research", "detailed", "comprehensive", "complex", "strategy"]

for keyword in complex_keywords:
    for msg in messages:
        if(keyword in str(msg).lower()):
            print("Found")
# Out:
# False

# %%
for msg in messages:
    print(str(msg).lower())
# Out:
# explain differences between agentic ai and generative ai in comprehensive way
# capital of india is ?
